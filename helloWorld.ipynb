# %% [markdown]
# <a href="https://colab.research.google.com/github/hermip/HtmlCssTutorial/blob/master/helloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import libraries

# %%
#Run this to install mplfinance module

# !pip install mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import mplfinance as mpf
import datetime

# %%
# Define the stock symbol and the desired time range
stock_symbol = 'ETH-EUR'
start_date = datetime.datetime.now() - datetime.timedelta(days=1)
end_date = datetime.datetime.now()

# Download the historical data for the stock
df = yf.download(stock_symbol, start=start_date, end=end_date, interval='30m')

# Plot the historical data
ap2 = [ mpf.make_addplot(df['Low'],color='g',panel=0),
        mpf.make_addplot(df['High'],color='b',panel=0),
      ]
mpf.plot(df,type='candle',main_panel=0, style = 'checkers', addplot=ap2)
# Out:
# [*********************100%***********************]  1 of 1 completed
